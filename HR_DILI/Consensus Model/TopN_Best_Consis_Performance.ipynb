# %%
# _*_ coding: utf-8 _*_
# @Time : $[DATE] $[TIME]
# @Author : G

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, f1_score, balanced_accuracy_score, matthews_corrcoef
import itertools

# Evaluation Metrics
def accuracy(y_true, y_pred):
    return accuracy_score(y_true, y_pred)

def precision(y_true, y_pred):
    return precision_score(y_true, y_pred, pos_label=1, average="binary")

def recall(y_true, y_pred):
    return recall_score(y_true, y_pred, pos_label=1, average="binary")

def auc(y_true, y_scores):
    return roc_auc_score(y_true, y_scores)

def mcc(y_true, y_pred):
    return matthews_corrcoef(y_true, y_pred)

def new_confusion_matrix(y_true, y_pred):
    return confusion_matrix(y_true, y_pred, labels=[0, 1])

def sp(y_true, y_pred):
    cm = new_confusion_matrix(y_true, y_pred)
    return cm[0, 0] * 1.0 / (cm[0, 0] + cm[0, 1])

def BACC(y_true, y_pred):
    return balanced_accuracy_score(y_true, y_pred)

def f1(y_true, y_pred):
    return f1_score(y_true, y_pred)

# ---> Loading prediction & Pron data
data = pd.read_csv('Seed2021_Consensus_test.csv', sep=',')
SMILES = data[['SMILES']]
y_true = data[['label']].values
Num_test = len(y_true)

# GCN
Label_GCN_pred = data[['label_GCN_pred']].values
Prediction_GCN_prob = data[['Prob_GCN']].values

# GAT
Label_GAT_pred = data[['label_GAT_pred']].values
Prediction_GAT_prob = data[['Prob_GAT']].values

# AttentiveFP
Label_AttentiveFP_pred = data[['label_AttentiveFP_pred']].values
Prediction_AttentiveFP_prob = data[['Prob_AttentiveFP']].values

# GraphSAGE
Label_GraphSAGE_pred = data[['label_GraphSAGE_pred']].values
Prediction_GraphSAGE_prob = data[['Prob_GraphSAGE']].values

# RF_MACCS
Label_RF_MACCS_pred = data[['label_RF_MACCS_pred']].values
Prediction_RF_MACCS_prob = data[['Prob_RF_MACCS']].values

# RF_Morgan
Label_RF_Morgan_pred = data[['label_RF_Morgan_pred']].values
Prediction_RF_Morgan_prob = data[['Prob_RF_Morgan']].values

def pred_read(name):
    The_pred = 'Label_' + '{}'.format(name) + '_pred'
    return The_pred
def prob_read(name):
    The_prob = 'Prediction_' + '{}'.format(name) + '_prob'
    return The_prob

# %%
# ---> Consistency Model
# ----> Soft Voting, using predicted class labels for majority rule voting

## chose two of six
a = 1
Model_list = list(itertools.combinations(['GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan'], 2))
Comb_AUC = []
Model_index = []
Model_names = []
Model_AUC = []
Model_ACC = []
Model_F1 = []
Model_BACC = []
Model_Precision = []
Model_Recall = []
Model_MCC = []
Model_SP = []
for i in Model_list:
    print('-' * 30 + 'The time {}'.format(a) + ' ***')
    pred1_name = pred_read(i[0])
    pred1 = locals()[pred1_name]
    prob1_name = prob_read(i[0])
    prob1 = locals()[prob1_name]

    pred2_name = pred_read(i[1])
    pred2 = locals()[pred2_name]
    prob2_name = prob_read(i[1])
    prob2 = locals()[prob2_name]

    Model_index.append(a)
    a = a + 1
    print('This Combination Models: {}'.format(i))

    y_pred_comb = []
    y_prob_comb = []
    for j in range(Num_test):
        comb_y_pred = pred1[j] + pred2[j]
        comb_y_prob = np.mean(prob1[j] + prob2[j])
        y_prob_comb.append(comb_y_prob)
        if int(comb_y_prob) >= 0.5:
            y_pred_comb.append(1)
        else:
            y_pred_comb.append(0)
    print('-' * 30 + 'Combination Model Top' + '-' * 30)
    print('ACC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('F1: {:.4f}'.format(f1(y_true, y_pred_comb)))
    print('BACC: {:.4f}'.format(BACC(y_true, y_pred_comb)))
    print('Precision: {:.4f}'.format(precision(y_true, y_pred_comb)))
    print('Recall: {:.4f}'.format(recall(y_true, y_pred_comb)))
    print('MCC: {:.4f}'.format(mcc(y_true, y_pred_comb)))
    print('SP: {:.4f}'.format(sp(y_true, y_pred_comb)))
    print('AUC: {:.4f}'.format(auc(y_true, y_prob_comb)))

    AUC = auc(y_true, y_prob_comb)
    Comb_AUC.append(AUC)
print('Combination Model AUC List: ')
print(Comb_AUC)

# Pick the best model by AUC performance
Max_AUC_location = np.where(Comb_AUC == np.max(Comb_AUC))
index_Max = Max_AUC_location[0].tolist()

for x in index_Max:
    print('The best model is combination Number --> {:.0f}'.format(x))
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
    print(Model_list[x])
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
# Out:
# ------------------------------The time 1 ***
# This Combination Models: ('GCN', 'GAT')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5255
# F1: 0.6033
# BACC: 0.5074
# Precision: 0.5823
# Recall: 0.6259
# MCC: 0.0150
# SP: 0.3889
# AUC: 0.5137
# ------------------------------The time 2 ***
# This Combination Models: ('GCN', 'AttentiveFP')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5098
# F1: 0.5847
# BACC: 0.4938
# Precision: 0.5714
# Recall: 0.5986
# MCC: -0.0126
# SP: 0.3889
# AUC: 0.4722
# ------------------------------The time 3 ***
# This Combination Models: ('GCN', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7608
# F1: 0.7932
# BACC: 0.7544
# Precision: 0.7905
# Recall: 0.7959
# MCC: 0.5095
# SP: 0.7130
# AUC: 0.8614
# ------------------------------The time 4 ***
# This Combination Models: ('GCN', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.4824
# F1: 0.5570
# BACC: 0.4675
# Precision: 0.5497
# Recall: 0.5646
# MCC: -0.0654
# SP: 0.3704
# AUC: 0.4757
# ------------------------------The time 5 ***
# This Combination Models: ('GCN', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.4784
# F1: 0.5581
# BACC: 0.4616
# Precision: 0.5455
# Recall: 0.5714
# MCC: -0.0775
# SP: 0.3519
# AUC: 0.4746
# ------------------------------The time 6 ***
# This Combination Models: ('GAT', 'AttentiveFP')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5608
# F1: 0.6340
# BACC: 0.5429
# Precision: 0.6101
# Recall: 0.6599
# MCC: 0.0875
# SP: 0.4259
# AUC: 0.5545
# ------------------------------The time 7 ***
# This Combination Models: ('GAT', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.8157
# F1: 0.8449
# BACC: 0.8057
# Precision: 0.8205
# Recall: 0.8707
# MCC: 0.6200
# SP: 0.7407
# AUC: 0.9078
# ------------------------------The time 8 ***
# This Combination Models: ('GAT', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5176
# F1: 0.5967
# BACC: 0.4993
# Precision: 0.5759
# Recall: 0.6190
# MCC: -0.0013
# SP: 0.3796
# AUC: 0.5377
# ------------------------------The time 9 ***
# This Combination Models: ('GAT', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5176
# F1: 0.5967
# BACC: 0.4993
# Precision: 0.5759
# Recall: 0.6190
# MCC: -0.0013
# SP: 0.3796
# AUC: 0.5353
# ------------------------------The time 10 ***
# This Combination Models: ('AttentiveFP', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.9216
# F1: 0.9338
# BACC: 0.9148
# Precision: 0.9097
# Recall: 0.9592
# MCC: 0.8396
# SP: 0.8704
# AUC: 0.9543
# ------------------------------The time 11 ***
# This Combination Models: ('AttentiveFP', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5608
# F1: 0.6387
# BACC: 0.5404
# Precision: 0.6074
# Recall: 0.6735
# MCC: 0.0832
# SP: 0.4074
# AUC: 0.5269
# ------------------------------The time 12 ***
# This Combination Models: ('AttentiveFP', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5490
# F1: 0.6302
# BACC: 0.5278
# Precision: 0.5976
# Recall: 0.6667
# MCC: 0.0573
# SP: 0.3889
# AUC: 0.5256
# ------------------------------The time 13 ***
# This Combination Models: ('GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.9373
# F1: 0.9470
# BACC: 0.9308
# Precision: 0.9226
# Recall: 0.9728
# MCC: 0.8721
# SP: 0.8889
# AUC: 0.9557
# ------------------------------The time 14 ***
# This Combination Models: ('GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.9373
# F1: 0.9470
# BACC: 0.9308
# Precision: 0.9226
# Recall: 0.9728
# MCC: 0.8721
# SP: 0.8889
# AUC: 0.9605
# ------------------------------The time 15 ***
# This Combination Models: ('RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5098
# F1: 0.5875
# BACC: 0.4925
# Precision: 0.5705
# Recall: 0.6054
# MCC: -0.0151
# SP: 0.3796
# AUC: 0.5246
# Combination Model AUC List:
# [0.513668430335097, 0.4722222222222222, 0.8613630637440162, 0.47568657092466615, 0.4745527840765936, 0.5544847568657093, 0.9078483245149912, 0.5377299067775259, 0.5352733686067019, 0.9543335852859663, 0.5268959435626102, 0.525573192239859, 0.9556563366087176, 0.960506424792139, 0.5246283698664651]
# The best model is combination Number --> 13
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
# ('GraphSAGE', 'RF_Morgan')
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*

# %%
# -----> Soft Voting, using predict the class label based on the argmax of the sum of predicted probabilities
a = 1
Model_list = list(itertools.combinations(['GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan'], 3))
Comb_AUC = []
Model_index = []
Model_names = []
Model_AUC = []
Model_ACC = []
Model_F1 = []
Model_BACC = []
Model_Precision = []
Model_Recall= []
Model_MCC = []
Model_SP = []
for i in Model_list:
    print('-' * 30 + 'The time {}'.format(a) + ' ***')
    pred1_name = pred_read(i[0])
    pred1 = locals()[pred1_name]
    prob1_name = prob_read(i[0])
    prob1 = locals()[prob1_name]

    pred2_name = pred_read(i[1])
    pred2 = locals()[pred2_name]
    prob2_name = prob_read(i[1])
    prob2 = locals()[prob2_name]

    pred3_name = pred_read(i[2])
    pred3 = locals()[pred3_name]
    prob3_name = prob_read(i[2])
    prob3 = locals()[prob3_name]

    Model_index.append(a)
    a = a + 1
    print('This Combination Models: {}'.format(i))

    y_pred_comb = []
    y_prob_comb = []
    for j in range(Num_test):
        comb_y_prob = np.mean(prob1[j] + prob2[j] + prob3[j])
        y_prob_comb.append(comb_y_prob)
        # prob > 0.5 ---> label =1
        if int(comb_y_prob) >= 0.5:
            y_pred_comb.append(1)
        else:
            y_pred_comb.append(0)
    print('-' * 30 + 'Combination Model Top' + '-' * 30)
    print('ACC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('F1: {:.4f}'.format(f1(y_true, y_pred_comb)))
    print('BACC: {:.4f}'.format(BACC(y_true, y_pred_comb)))
    print('Precision: {:.4f}'.format(precision(y_true, y_pred_comb)))
    print('Recall: {:.4f}'.format(recall(y_true, y_pred_comb)))
    print('MCC: {:.4f}'.format(mcc(y_true, y_pred_comb)))
    print('SP: {:.4f}'.format(sp(y_true, y_pred_comb)))
    print('AUC: {:.4f}'.format(auc(y_true, y_prob_comb)))

    AUC = auc(y_true, y_prob_comb)
    Comb_AUC.append(AUC)
print('Combination Model AUC List: ')
print(Comb_AUC)

# Pick the best model by AUC performance
Max_AUC_location = np.where(Comb_AUC == np.max(Comb_AUC))
index_Max = Max_AUC_location[0].tolist()
for x in index_Max:
    print('The best model is combination Number --> {:.0f}'.format(x))
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
    print(Model_list[x])
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
# Out:
# ------------------------------The time 1 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5686
# F1: 0.6961
# BACC: 0.5165
# Precision: 0.5860
# Recall: 0.8571
# MCC: 0.0449
# SP: 0.1759
# AUC: 0.5062
# ------------------------------The time 2 ***
# This Combination Models: ('GCN', 'GAT', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6902
# F1: 0.7836
# BACC: 0.6392
# Precision: 0.6560
# Recall: 0.9728
# MCC: 0.3905
# SP: 0.3056
# AUC: 0.8202
# ------------------------------The time 3 ***
# This Combination Models: ('GCN', 'GAT', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5529
# F1: 0.6851
# BACC: 0.5005
# Precision: 0.5767
# Recall: 0.8435
# MCC: 0.0013
# SP: 0.1574
# AUC: 0.4970
# ------------------------------The time 4 ***
# This Combination Models: ('GCN', 'GAT', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5490
# F1: 0.6832
# BACC: 0.4958
# Precision: 0.5741
# Recall: 0.8435
# MCC: -0.0114
# SP: 0.1481
# AUC: 0.4899
# ------------------------------The time 5 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7294
# F1: 0.8089
# BACC: 0.6818
# Precision: 0.6822
# Recall: 0.9932
# MCC: 0.4891
# SP: 0.3704
# AUC: 0.8279
# ------------------------------The time 6 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5529
# F1: 0.6851
# BACC: 0.5005
# Precision: 0.5767
# Recall: 0.8435
# MCC: 0.0013
# SP: 0.1574
# AUC: 0.4930
# ------------------------------The time 7 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5608
# F1: 0.6906
# BACC: 0.5085
# Precision: 0.5814
# Recall: 0.8503
# MCC: 0.0231
# SP: 0.1667
# AUC: 0.4909
# ------------------------------The time 8 ***
# This Combination Models: ('GCN', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7255
# F1: 0.8077
# BACC: 0.6759
# Precision: 0.6774
# Recall: 1.0000
# MCC: 0.4882
# SP: 0.3519
# AUC: 0.8284
# ------------------------------The time 9 ***
# This Combination Models: ('GCN', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7137
# F1: 0.8000
# BACC: 0.6633
# Precision: 0.6697
# Recall: 0.9932
# MCC: 0.4581
# SP: 0.3333
# AUC: 0.8234
# ------------------------------The time 10 ***
# This Combination Models: ('GCN', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5176
# F1: 0.6555
# BACC: 0.4674
# Precision: 0.5571
# Recall: 0.7959
# MCC: -0.0845
# SP: 0.1389
# AUC: 0.4992
# ------------------------------The time 11 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7255
# F1: 0.8056
# BACC: 0.6784
# Precision: 0.6808
# Recall: 0.9864
# MCC: 0.4753
# SP: 0.3704
# AUC: 0.8779
# ------------------------------The time 12 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5647
# F1: 0.6992
# BACC: 0.5082
# Precision: 0.5811
# Recall: 0.8776
# MCC: 0.0242
# SP: 0.1389
# AUC: 0.5437
# ------------------------------The time 13 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5529
# F1: 0.6902
# BACC: 0.4968
# Precision: 0.5747
# Recall: 0.8639
# MCC: -0.0093
# SP: 0.1296
# AUC: 0.5391
# ------------------------------The time 14 ***
# This Combination Models: ('GAT', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7216
# F1: 0.8044
# BACC: 0.6725
# Precision: 0.6759
# Recall: 0.9932
# MCC: 0.4737
# SP: 0.3519
# AUC: 0.8838
# ------------------------------The time 15 ***
# This Combination Models: ('GAT', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7216
# F1: 0.8033
# BACC: 0.6738
# Precision: 0.6776
# Recall: 0.9864
# MCC: 0.4674
# SP: 0.3611
# AUC: 0.8830
# ------------------------------The time 16 ***
# This Combination Models: ('GAT', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5647
# F1: 0.6959
# BACC: 0.5107
# Precision: 0.5826
# Recall: 0.8639
# MCC: 0.0300
# SP: 0.1574
# AUC: 0.5305
# ------------------------------The time 17 ***
# This Combination Models: ('AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7412
# F1: 0.8167
# BACC: 0.6944
# Precision: 0.6901
# Recall: 1.0000
# MCC: 0.5181
# SP: 0.3889
# AUC: 0.8794
# ------------------------------The time 18 ***
# This Combination Models: ('AttentiveFP', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7255
# F1: 0.8077
# BACC: 0.6759
# Precision: 0.6774
# Recall: 1.0000
# MCC: 0.4882
# SP: 0.3519
# AUC: 0.8772
# ------------------------------The time 19 ***
# This Combination Models: ('AttentiveFP', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5569
# F1: 0.6817
# BACC: 0.5088
# Precision: 0.5817
# Recall: 0.8231
# MCC: 0.0224
# SP: 0.1944
# AUC: 0.5208
# ------------------------------The time 20 ***
# This Combination Models: ('GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.7255
# F1: 0.8066
# BACC: 0.6772
# Precision: 0.6791
# Recall: 0.9932
# MCC: 0.4814
# SP: 0.3611
# AUC: 0.7894
# Combination Model AUC List:
# [0.5062358276643992, 0.8201688082640464, 0.49703955656336607, 0.48992189468379943, 0.8278533635676493, 0.493008314436886, 0.49086671705719326, 0.8283572688334593, 0.8233812043335853, 0.49918115394305873, 0.8778659611992946, 0.5436507936507937, 0.5391156462585034, 0.8837868480725624, 0.8830309901738472, 0.530549256739733, 0.8794406651549509, 0.8771730914588057, 0.5207860922146637, 0.7894305870496348]
# The best model is combination Number --> 13
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
# ('GAT', 'GraphSAGE', 'RF_MACCS')
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*

# %%
# chose four of six
a = 1
Model_list = list(itertools.combinations(['GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan'], 4))
Comb_AUC = []
Model_index = []
Model_names = []
Model_AUC = []
Model_ACC = []
Model_F1 = []
Model_BACC = []
Model_Precision = []
Model_Recall= []
Model_MCC = []
Model_SP = []
for i in Model_list:
    print('-' * 30 + 'The time {}'.format(a) + ' ***')
    pred1_name = pred_read(i[0])
    pred1 = locals()[pred1_name]
    prob1_name = prob_read(i[0])
    prob1 = locals()[prob1_name]

    pred2_name = pred_read(i[1])
    pred2 = locals()[pred2_name]
    prob2_name = prob_read(i[1])
    prob2 = locals()[prob2_name]

    pred3_name = pred_read(i[2])
    pred3 = locals()[pred3_name]
    prob3_name = prob_read(i[2])
    prob3 = locals()[prob3_name]

    pred4_name = pred_read(i[3])
    pred4 = locals()[pred4_name]
    prob4_name = prob_read(i[3])
    prob4 = locals()[prob4_name]

    Model_index.append(a)
    a = a + 1
    print('This Combination Models: {}'.format(i))

    y_pred_comb = []
    y_prob_comb = []
    for j in range(Num_test):
        comb_y_pred = pred1[j] + pred2[j] + pred3[j] + pred4[j]
        comb_y_prob = np.mean(prob1[j] + prob2[j] + prob3[j] + prob4[j])
        y_prob_comb.append(comb_y_prob)
        # 2/4 ---> label =1
        if int(comb_y_prob) >= 0.5:
            y_pred_comb.append(1)
        else:
            y_pred_comb.append(0)
    print('-' * 30 + 'Combination Model Top' + '-' * 30)
    print('ACC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('F1: {:.4f}'.format(f1(y_true, y_pred_comb)))
    print('BACC: {:.4f}'.format(BACC(y_true, y_pred_comb)))
    print('Precision: {:.4f}'.format(precision(y_true, y_pred_comb)))
    print('Recall: {:.4f}'.format(recall(y_true, y_pred_comb)))
    print('MCC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('SP: {:.4f}'.format(sp(y_true, y_pred_comb)))
    print('AUC: {:.4f}'.format(auc(y_true, y_prob_comb)))

    AUC = auc(y_true, y_prob_comb)
    Comb_AUC.append(AUC)
print('Combination Model AUC List: ')
print(Comb_AUC)

# Pick the best model by AUC performance
Max_AUC_location = np.where(Comb_AUC == np.max(Comb_AUC))
index_Max = Max_AUC_location[0].tolist()
for x in index_Max:
    print('The best model is combination Number --> {:.0f}'.format(x))
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
    print(Model_list[x])
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
# Out:
# ------------------------------The time 1 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6471
# F1: 0.7656
# BACC: 0.5833
# Precision: 0.6203
# Recall: 1.0000
# MCC: 0.6471
# SP: 0.1667
# AUC: 0.7997
# ------------------------------The time 2 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5725
# F1: 0.7169
# BACC: 0.5064
# Precision: 0.5798
# Recall: 0.9388
# MCC: 0.5725
# SP: 0.0741
# AUC: 0.5079
# ------------------------------The time 3 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5725
# F1: 0.7169
# BACC: 0.5064
# Precision: 0.5798
# Recall: 0.9388
# MCC: 0.5725
# SP: 0.0741
# AUC: 0.5055
# ------------------------------The time 4 ***
# This Combination Models: ('GCN', 'GAT', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6431
# F1: 0.7636
# BACC: 0.5787
# Precision: 0.6176
# Recall: 1.0000
# MCC: 0.6431
# SP: 0.1574
# AUC: 0.7998
# ------------------------------The time 5 ***
# This Combination Models: ('GCN', 'GAT', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6353
# F1: 0.7584
# BACC: 0.5707
# Precision: 0.6134
# Recall: 0.9932
# MCC: 0.6353
# SP: 0.1481
# AUC: 0.7959
# ------------------------------The time 6 ***
# This Combination Models: ('GCN', 'GAT', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5725
# F1: 0.7154
# BACC: 0.5077
# Precision: 0.5805
# Recall: 0.9320
# MCC: 0.5725
# SP: 0.0833
# AUC: 0.5042
# ------------------------------The time 7 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6392
# F1: 0.7617
# BACC: 0.5741
# Precision: 0.6151
# Recall: 1.0000
# MCC: 0.6392
# SP: 0.1481
# AUC: 0.7868
# ------------------------------The time 8 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6392
# F1: 0.7617
# BACC: 0.5741
# Precision: 0.6151
# Recall: 1.0000
# MCC: 0.6392
# SP: 0.1481
# AUC: 0.7824
# ------------------------------The time 9 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5529
# F1: 0.7000
# BACC: 0.4894
# Precision: 0.5708
# Recall: 0.9048
# MCC: 0.5529
# SP: 0.0741
# AUC: 0.5042
# ------------------------------The time 10 ***
# This Combination Models: ('GCN', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6353
# F1: 0.7597
# BACC: 0.5694
# Precision: 0.6125
# Recall: 1.0000
# MCC: 0.6353
# SP: 0.1389
# AUC: 0.7425
# ------------------------------The time 11 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6275
# F1: 0.7558
# BACC: 0.5602
# Precision: 0.6074
# Recall: 1.0000
# MCC: 0.6275
# SP: 0.1204
# AUC: 0.8486
# ------------------------------The time 12 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6235
# F1: 0.7538
# BACC: 0.5556
# Precision: 0.6049
# Recall: 1.0000
# MCC: 0.6235
# SP: 0.1111
# AUC: 0.8415
# ------------------------------The time 13 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5765
# F1: 0.7202
# BACC: 0.5098
# Precision: 0.5816
# Recall: 0.9456
# MCC: 0.5765
# SP: 0.0741
# AUC: 0.5319
# ------------------------------The time 14 ***
# This Combination Models: ('GAT', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6392
# F1: 0.7617
# BACC: 0.5741
# Precision: 0.6151
# Recall: 1.0000
# MCC: 0.6392
# SP: 0.1481
# AUC: 0.7955
# ------------------------------The time 15 ***
# This Combination Models: ('AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6549
# F1: 0.7696
# BACC: 0.5926
# Precision: 0.6255
# Recall: 1.0000
# MCC: 0.6549
# SP: 0.1852
# AUC: 0.7794
# Combination Model AUC List:
# [0.799697656840514, 0.5079365079365079, 0.5055429579239102, 0.7997606449987402, 0.7959183673469388, 0.504220206601159, 0.786785084404132, 0.7824389014865205, 0.504220206601159, 0.7425044091710759, 0.8485764676240868, 0.8415217939027463, 0.5319349962207105, 0.7955404383975813, 0.7794154698916603]
# The best model is combination Number --> 10
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
# ('GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*

# %%
# chose five of six
a = 1
Model_list = list(itertools.combinations(['GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan'], 5))
Comb_AUC = []
Model_index = []
Model_names = []
Model_AUC = []
Model_ACC = []
Model_F1 = []
Model_BACC = []
Model_Precision = []
Model_Recall= []
Model_MCC = []
Model_SP = []
for i in Model_list:
    print('-' * 30 + 'The time {}'.format(a) + ' ***')
    pred1_name = pred_read(i[0])
    pred1 = locals()[pred1_name]
    prob1_name = prob_read(i[0])
    prob1 = locals()[prob1_name]

    pred2_name = pred_read(i[1])
    pred2 = locals()[pred2_name]
    prob2_name = prob_read(i[1])
    prob2 = locals()[prob2_name]

    pred3_name = pred_read(i[2])
    pred3 = locals()[pred3_name]
    prob3_name = prob_read(i[2])
    prob3 = locals()[prob3_name]

    pred4_name = pred_read(i[3])
    pred4 = locals()[pred4_name]
    prob4_name = prob_read(i[3])
    prob4 = locals()[prob4_name]

    pred5_name = pred_read(i[4])
    pred5 = locals()[pred5_name]
    prob5_name = prob_read(i[4])
    prob5 = locals()[prob5_name]

    Model_index.append(a)
    a = a + 1
    print('This Combination Models: {}'.format(i))

    y_pred_comb = []
    y_prob_comb = []
    for j in range(Num_test):
        comb_y_pred = pred1[j] + pred2[j] + pred3[j] + pred4[j] + pred5[j]
        comb_y_prob = np.mean(prob1[j] + prob2[j] + prob3[j] + prob4[j] + prob5[j])
        y_prob_comb.append(comb_y_prob)
        # 2/5 ---> label =1
        if int(comb_y_prob) >= 0.5:
            y_pred_comb.append(1)
        else:
            y_pred_comb.append(0)
    print('-' * 30 + 'Combination Model Top' + '-' * 30)
    print('ACC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('F1: {:.4f}'.format(f1(y_true, y_pred_comb)))
    print('BACC: {:.4f}'.format(BACC(y_true, y_pred_comb)))
    print('Precision: {:.4f}'.format(precision(y_true, y_pred_comb)))
    print('Recall: {:.4f}'.format(recall(y_true, y_pred_comb)))
    print('MCC: {:.4f}'.format(mcc(y_true, y_pred_comb)))
    print('SP: {:.4f}'.format(sp(y_true, y_pred_comb)))
    print('AUC: {:.4f}'.format(auc(y_true, y_prob_comb)))

    AUC = auc(y_true, y_prob_comb)
    Comb_AUC.append(AUC)
print('Combination Model AUC List: ')
print(Comb_AUC)

# Pick the best model by AUC performance
Max_AUC_location = np.where(Comb_AUC == np.max(Comb_AUC))
index_Max = Max_AUC_location[0].tolist()
for x in index_Max:
    print('The best model is combination Number --> {:.0f}'.format(x))
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
    print(Model_list[x])
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
# Out:
# ------------------------------The time 1 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6078
# F1: 0.7462
# BACC: 0.5370
# Precision: 0.5951
# Recall: 1.0000
# MCC: 0.2100
# SP: 0.0741
# AUC: 0.7796
# ------------------------------The time 2 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6078
# F1: 0.7462
# BACC: 0.5370
# Precision: 0.5951
# Recall: 1.0000
# MCC: 0.2100
# SP: 0.0741
# AUC: 0.7724
# ------------------------------The time 3 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.5765
# F1: 0.7245
# BACC: 0.5061
# Precision: 0.5796
# Recall: 0.9660
# MCC: 0.0313
# SP: 0.0463
# AUC: 0.5103
# ------------------------------The time 4 ***
# This Combination Models: ('GCN', 'GAT', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6118
# F1: 0.7481
# BACC: 0.5417
# Precision: 0.5976
# Recall: 1.0000
# MCC: 0.2232
# SP: 0.0833
# AUC: 0.7394
# ------------------------------The time 5 ***
# This Combination Models: ('GCN', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6039
# F1: 0.7443
# BACC: 0.5324
# Precision: 0.5927
# Recall: 1.0000
# MCC: 0.1960
# SP: 0.0648
# AUC: 0.7315
# ------------------------------The time 6 ***
# This Combination Models: ('GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6078
# F1: 0.7462
# BACC: 0.5370
# Precision: 0.5951
# Recall: 1.0000
# MCC: 0.2100
# SP: 0.0741
# AUC: 0.7773
# Combination Model AUC List:
# [0.7796044343663391, 0.7723607961703199, 0.5103300579491056, 0.7393550012597633, 0.7315444696397078, 0.7772738725119678]
# The best model is combination Number --> 0
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
# ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS')
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*

# %%
# All six
a = 1
Model_list = list(itertools.combinations(['GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan'], 6))
Comb_AUC = []
Model_index = []
Model_names = []
Model_AUC = []
Model_ACC = []
Model_F1 = []
Model_BACC = []
Model_Precision = []
Model_Recall= []
Model_MCC = []
Model_SP = []
for i in Model_list:
    print('-' * 30 + 'The time {}'.format(a) + ' ***')
    pred1_name = pred_read(i[0])
    pred1 = locals()[pred1_name]
    prob1_name = prob_read(i[0])
    prob1 = locals()[prob1_name]

    pred2_name = pred_read(i[1])
    pred2 = locals()[pred2_name]
    prob2_name = prob_read(i[1])
    prob2 = locals()[prob2_name]

    pred3_name = pred_read(i[2])
    pred3 = locals()[pred3_name]
    prob3_name = prob_read(i[2])
    prob3 = locals()[prob3_name]

    pred4_name = pred_read(i[3])
    pred4 = locals()[pred4_name]
    prob4_name = prob_read(i[3])
    prob4 = locals()[prob4_name]

    pred5_name = pred_read(i[4])
    pred5 = locals()[pred5_name]
    prob5_name = prob_read(i[4])
    prob5 = locals()[prob4_name]

    pred6_name = pred_read(i[5])
    pred6 = locals()[pred6_name]
    prob6_name = prob_read(i[5])
    prob6 = locals()[prob6_name]

    Model_index.append(a)
    a = a + 1
    print('This Combination Models: {}'.format(i))

    y_pred_comb = []
    y_prob_comb = []
    for j in range(Num_test):
        comb_y_pred = pred1[j] + pred2[j] + pred3[j] + pred4[j] + pred5[j] + pred6[j]
        comb_y_prob = np.mean(prob1[j] + prob2[j] + prob3[j] + prob4[j] + prob5[j] + prob6[j])
        y_prob_comb.append(comb_y_prob)
        # 3/6 ---> label =1
        if int(comb_y_prob) >= 0.5:
            y_pred_comb.append(1)
        else:
            y_pred_comb.append(0)
    print('-' * 30 + 'Combination Model Top' + '-' * 30)
    print('ACC: {:.4f}'.format(accuracy(y_true, y_pred_comb)))
    print('F1: {:.4f}'.format(f1(y_true, y_pred_comb)))
    print('BACC: {:.4f}'.format(BACC(y_true, y_pred_comb)))
    print('Precision: {:.4f}'.format(precision(y_true, y_pred_comb)))
    print('Recall: {:.4f}'.format(recall(y_true, y_pred_comb)))
    print('MCC: {:.4f}'.format(mcc(y_true, y_pred_comb)))
    print('SP: {:.4f}'.format(sp(y_true, y_pred_comb)))
    print('AUC: {:.4f}'.format(auc(y_true, y_prob_comb)))

    AUC = auc(y_true, y_prob_comb)
    Comb_AUC.append(AUC)
print('Combination Model AUC List: ')
print(Comb_AUC)

# Pick the best model by AUC performance
Max_AUC_location = np.where(Comb_AUC == np.max(Comb_AUC))
index_Max = Max_AUC_location[0].tolist()
for x in index_Max:
    print('The best model is combination Number --> {:.0f}'.format(x))
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
    print(Model_list[x])
    print('*- '*5 + 'Here is the best combination models' + ' -*'*5)
# Out:
# ------------------------------The time 1 ***
# This Combination Models: ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# ------------------------------Combination Model Top------------------------------
# ACC: 0.6078
# F1: 0.7462
# BACC: 0.5370
# Precision: 0.5951
# Recall: 1.0000
# MCC: 0.2100
# SP: 0.0741
# AUC: 0.9172
# Combination Model AUC List:
# [0.9171705719324768]
# The best model is combination Number --> 0
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
# ('GCN', 'GAT', 'AttentiveFP', 'GraphSAGE', 'RF_MACCS', 'RF_Morgan')
# *- *- *- *- *- Here is the best combination models -* -* -* -* -*
